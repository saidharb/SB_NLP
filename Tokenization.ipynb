# %% [markdown]
# # Tokenization

# %%
ord("h") # print out Unicode code point of a character
# Out:
# 104

# %%
# text from https://www.reedbeta.com/blog/programmers-intro-to-unicode/
text = "Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception."
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print('---')
print(text)
print("length:", len(text))
print('---')
print(tokens)
print("length:", len(tokens))
# Out:
# ---
# Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.
# length: 533
# ---
# ...

# %%
a = '/'.encode('utf-8') # utf-8 encoding basically creates one to four bytes
# i.e. a byte is made of 8 bits (which are 0 or 1) --> 2**0 to 2**7
# If all bits are 1, then the byte has the value 255, i.e. there are 256 
# different possibilities for each byte
list(a)
# Out:
# [47]

# %%
def create_empty_pair_dict(tokens):
    unique_tokens = set(tokens)
    pair_dict = {}
    for unique_token in unique_tokens:
        pair_dict[unique_token] = {unique_token2:0 for unique_token2 in unique_tokens}

    return pair_dict

# %%
def count_most_frequent_pairs(tokens):
    pair_dict = create_empty_pair_dict(tokens)
    for i in range(len(tokens)-1):
        first_token = tokens[i]
        second_token = tokens[i+1]
        pair_dict[first_token][second_token] += 1
    return pair_dict

# %%
def get_counts(pair_dict):
    new_pair_dict = {}
    for first_token in pair_dict.keys():
        for second_token in pair_dict[first_token].keys():
            token_combination = str(first_token) + "-" + str(second_token)
            new_pair_dict[token_combination] = pair_dict[first_token][second_token]

   # new_pair_dict = dict(sorted(new_pair_dict.items(), key = lambda item: item[1]))
    return new_pair_dict

# %%
count_dict = get_counts(count_most_frequent_pairs(tokens))
keys, values = list(count_dict.keys()), list(count_dict.values())
paired = zip(keys, values)
sorted_paired = sorted(paired, key=lambda x: x[1], reverse = True)
sorted_paired
# Out:
# [('101-32', 20),
#  ('240-159', 15),
#  ('226-128', 12),
#  ('105-110', 12),
#  ('32-97', 10),
#  ('97-110', 10),
#  ('115-32', 10),
#  ('32-116', 9),
#  ('116-104', 8),
#  ('159-133', 7),
#  ('159-135', 7),
#  ('97-114', 7),
#  ('128-140', 6),
#  ('140-240', 6),
#  ('32-105', 6),
#  ('101-114', 6),
#  ('104-101', 6),
#  ('109-101', 6),
#  ('110-100', 6),
#  ('110-103', 6),
#  ('239-189', 6),
#  ('111-114', 6),
#  ('114-32', 6),
#  ('116-32', 6),
#  ('32-115', 5),
#  ('44-32', 5),
#  ('100-101', 5),
#  ('110-32', 5),
#  ('115-116', 5),
#  ('117-115', 5),
#  ('32-85', 4),
#  ('32-102', 4),
#  ('32-111', 4),
#  ('32-119', 4),
#  ('85-110', 4),
#  ('97-109', 4),
#  ('99-111', 4),
#  ('100-32', 4),
#  ('101-97', 4),
#  ('103-32', 4),
#  ('104-97', 4),
#  ('105-99', 4),
#  ('110-105', 4),
#  ('110-116', 4),
#  ('111-100', 4),
#  ('111-117', 4),
#  ('114-105', 4),
#  ('115-44', 4),
#  ('116-101', 4),
#  ('116-105', 4),
#  ('32-100', 3),
#  ('32-98', 3),
#  ('32-109', 3),
#  ('32-240', 3),
# ...

# %%
byte_sequence = bytes([116, 104])

# Decode to a string
decoded_string = byte_sequence.decode('utf-8')
decoded_string
# Out:
# 'th'

# %%
c= list(a)

# %%
print(c)
# Out:
# ['a', 'b']

# %%
"101".decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 "101".decode('utf-8')
#
# AttributeError: 'str' object has no attribute 'decode'
